# %% [markdown]
# # Interactive Visualization Lab
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
import pandas as pd
import chart_studio.plotly as py
import cufflinks as cf
from ipywidgets import interact
import plotly.express as px
import plotly.graph_objs as go
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from datetime import datetime


cf.go_offline()
# Out:
# C:\Users\ferna\AppData\Local\Temp\ipykernel_12436\3458541319.py:8: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#
# C:\Users\ferna\AppData\Local\Temp\ipykernel_12436\3458541319.py:9: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
# ...

# %%
# %pip install dash
# Out:
# ...
#   Obtaining dependency information for dash from https://files.pythonhosted.org/packages/00/69/d0ee9c6524678e98d336464d5c898182794c6b2ba1e5507bc7010a126ce2/dash-2.14.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#     --------------------------------------- 0.1/10.4 MB 4.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/10.4 MB 3.5 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/10.4 MB 3.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.4 MB 3.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/10.4 MB 3.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/10.4 MB 3.2 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/10.4 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/10.4 MB 3.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.4 MB 3.1 MB/s eta 0:00:03
# ...

# %%
##%pip install plotly
##%pip install chart-studio
##%pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached chart_studio-1.1.0-py3-none-any.whl (64 kB)
# ...
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# ...

# %% [markdown]
# ## 1. Create an interactive bar chart showing total quantity and revenue by country (excluding United Kingdom) for the month of April 2011.

# %%
df=pd.read_excel('../data/Online Retail.xlsx')

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
data=df[df.Country!='United Kingdom']

data=data.loc[(data.InvoiceDate >= '2011-4-1') & (data.InvoiceDate <= '2011-4-30')]

data
# Out:
#         InvoiceNo         InvoiceDate StockCode  \
# 724        549667 2011-04-11 12:20:00    85123A
# 807        551163 2011-04-26 15:52:00    85123A
# 3320       550899 2011-04-21 12:07:00     22752
# 4880       550527 2011-04-19 10:48:00     84879
# 4882       550620 2011-04-19 13:39:00     84879
# ...           ...                 ...       ...
# 328231     550665 2011-04-20 09:31:00     23204
# 328238     550911 2011-04-21 13:11:00     23204
# 328244     551258 2011-04-27 12:02:00     23204
# 328681     551346 2011-04-28 09:12:00     23208
# 329262     550137 2011-04-14 13:59:00    44242B
#
#                                Description  Quantity  UnitPrice  Revenue  \
# 724     CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# 807     CREAM HANGING HEART T-LIGHT HOLDER         9       2.95    26.55
# 3320          SET 7 BABUSHKA NESTING BOXES         2       8.50    17.00
# 4880         ASSORTED COLOUR BIRD ORNAMENT        40       1.69    67.60
# ...

# %%
data = data[['Quantity', 'Revenue', 'Country']]

data = data.groupby('Country').sum()

# %%
data.head()
# Out:
#                  Quantity  Revenue
# Country
# Australia             224   421.60
# Austria               308   584.78
# Belgium              1170  1788.48
# Brazil                356  1143.60
# Channel Islands        96   243.00

# %%
##data.iplot(kind='bar', xTitle='Country', title='Cantidad total y beneficio')
# Out:
# <div>                            <div id="3e4ded49-cf99-4521-9b06-d2433682a11e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## 2.Create an interactive line chart showing quantity and revenue sold to France between January 1st and May 31st 2011.

# %%
filtered_data = df[(df['InvoiceDate'] >= '2011-01-01') & (df['InvoiceDate'] <= '2011-05-31') & (df['Country'] == 'France')]

# %%
filtered_data = filtered_data[['Country', 'Quantity', 'Revenue']]

# %%
filtered_data = filtered_data.groupby('Country').sum()

# %%
##filtered_data.iplot(kind='bar', xTitle='Country', title='Cantidad total y beneficio')
# Out:
# <div>                            <div id="a445c7c7-1b98-4c4f-a239-d0b3242b35ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## 3. Create an interactive scatter plot showing the relationship between average quantity (x-axis) and average unit price (y-axis) for the product PARTY BUNTING with the plot points color-coded by country (categories).

# %%
filtered_data = df[df['Description'] == 'PARTY BUNTING']

# %%
filtered_data.head()
# Out:
#         InvoiceNo         InvoiceDate StockCode    Description  Quantity  \
# 252864     536956 2010-12-03 12:43:00     47566  PARTY BUNTING         5
# 252865     537065 2010-12-05 11:57:00     47566  PARTY BUNTING         5
# 252866     537128 2010-12-05 12:15:00     47566  PARTY BUNTING         2
# 252867     537142 2010-12-05 12:57:00     47566  PARTY BUNTING         1
# 252868     537420 2010-12-06 15:18:00     47566  PARTY BUNTING         5
#
#         UnitPrice  Revenue  CustomerID         Country
# 252864       4.65    23.25       14210  United Kingdom
# 252865       4.65    23.25       12567          France
# 252866       4.65     9.30       12841  United Kingdom
# 252867       4.65     4.65       12748  United Kingdom
# 252868       4.65    23.25       17519  United Kingdom

# %%
filtered_data = filtered_data[['Country', 'Quantity', 'UnitPrice']]

# %%
filtered_data.head()
# Out:
#                Country  Quantity  UnitPrice
# 252864  United Kingdom         5       4.65
# 252865          France         5       4.65
# 252866  United Kingdom         2       4.65
# 252867  United Kingdom         1       4.65
# 252868  United Kingdom         5       4.65
# ...                ...       ...        ...
# 254255  United Kingdom         4       4.95
# 254256  United Kingdom         3       4.95
# 254257  United Kingdom         5       4.95
# 254258  United Kingdom         8       4.95
# 254259  United Kingdom         1       4.95
#
# [1396 rows x 3 columns]

# %%
avg_data = filtered_data.groupby('Country').agg({'Quantity': 'mean', 'UnitPrice': 'mean'}).reset_index()

##fig = px.scatter(
    avg_data,
    x='Quantity',
    y='UnitPrice',
    color='Country',
    title='Relationship Between Average Quantity and Average Unit Price for PARTY BUNTING'
)

# Show the interactive scatter plot
##fig.show()
# Out:
# <div>                            <div id="c0eee570-7df6-4a14-9c2a-dadd575ab048" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0eee570-7df6-4a14-9c2a-dadd575ab048")) {                    Plotly.newPlot(                        "c0eee570-7df6-4a14-9c2a-dadd575ab048",                        [{"hovertemplate":"Country=Australia\u003cbr\u003eQuantity=%{x}\u003cbr\u003eUnitPrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[33.125],"xaxis":"x","y":[4.7125],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Austria\u003cbr\u003eQuantity=%{x}\u003cbr\u003eUnitPrice=%{y}\u003cextra\u003e\u003c\u002fextra
# ...

# %% [markdown]
# ## 4. Create a set of interactive histograms showing the distributions of quantity per invoice for the following countries: EIRE, Germany, France, and Netherlands.

# %%
countries = ['EIRE', 'Germany', 'France', 'Netherlands']
filtered_data = df[df['Country'].isin(countries)]

##fig = px.box(
    filtered_data,
    x='Country',
    y='Quantity',
    title='Distribution of Quantity per Invoice by Country',
    labels={'Quantity': 'Quantity per Invoice'},
)

##fig.show()
# Out:
# <div>                            <div id="bb2ab08c-47b8-44fa-aeaf-f55f78f2257a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb2ab08c-47b8-44fa-aeaf-f55f78f2257a")) {                    Plotly.newPlot(                        "bb2ab08c-47b8-44fa-aeaf-f55f78f2257a",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eQuantity per Invoice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["EIRE","EIRE","Netherlands","EIRE","EIRE","EIRE","EIRE","EIRE","EIRE","Netherlands","EIRE","Netherlands","EIRE","France","EIRE","EIRE","EIRE","EIRE","EIRE","Netherlands","EIRE","EIRE","EIRE","EIRE","Fr
# ...

# %% [markdown]
# ## 5. Create an interactive side-by-side bar chart showing the revenue by country listed below (bars) for each of the products listed below.

# %%
filtered_data = df[['Country', 'Revenue', 'Description']]

# %%
filtered_data = filtered_data[filtered_data['Country'].isin(['EIRE', 'Germany', 'France', 'Netherlands'])][['Country', 'Revenue', 'Description']]

# %%
filtered_data = filtered_data[filtered_data['Description'] == 'PARTY BUNTING']

# %%
app = dash.Dash(__name__)

# Agregar columnas de año y mes para facilitar el filtrado
filtered_data['Year'] = filtered_data['InvoiceDate'].dt.year
filtered_data['Month'] = filtered_data['InvoiceDate'].dt.month

# Layout de la aplicación web
app.layout = html.Div([
    html.H1("Cantidad vendida por día en el Reino Unido"),
    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': year, 'value': year} for year in filtered_data['Year'].unique()],
        value=filtered_data['Year'].max()
    ),
    dcc.Dropdown(
        id='month-dropdown',
        options=[{'label': month, 'value': month} for month in filtered_data['Month'].unique()],
        value=filtered_data['Month'].max()
    ),
    dcc.Graph(id='line-chart')
])

# Callback para actualizar el gráfico en función de las selecciones en los menús desplegables
@app.callback(
    Output('line-chart', 'figure'),
    Input('year-dropdown', 'value'),
    Input('month-dropdown', 'value')
)
def update_line_chart(selected_year, selected_month):
    filtered_data_filtered = filtered_data[(filtered_data['Year'] == selected_year) & (filtered_data['Month'] == selected_month)]
    fig = px.line(filtered_data_filtered, x='InvoiceDate', y='Quantity', title=f'Cantidad vendida por día en el Reino Unido ({selected_year}/{selected_month})')
    return fig

# Ejecutar la aplicación Dash
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# <div>                            <div id="fadca0d7-41fa-4013-8f47-38822650a25c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fadca0d7-41fa-4013-8f47-38822650a25c")) {                    Plotly.newPlot(                        "fadca0d7-41fa-4013-8f47-38822650a25c",                        [{"alignmentgroup":"True","hovertemplate":"Description=PARTY BUNTING<br>Country=%{x}<br>Ingresos (en $)=%{y}<extra></extra>","legendgroup":"PARTY BUNTING","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PARTY BUNTING","offsetgroup":"PARTY BUNTING","orientation":"v","showlegend":true,"textposition":"auto","x":["France","France","Germany","France","Germany","France","Germany","EIRE","France","EIRE","France","EIRE","EIRE","France","France","EIRE","France"
# ...

# %% [markdown]
# ## 6. Create an interactive line chart showing quantity sold by day for the United Kingdom. Add drop-down boxes for Year and Month that allow you to filter the date range that appears in the chart.

# %%
filtered_data = filtered_data[filtered_data['Country'].isin(['United Kingdom'])]

# %%
filtered_data = df[['Country', 'InvoiceDate', 'Quantity']]

# %%
filtered_data.head()
# Out:
#           Country         InvoiceDate  Quantity
# 0  United Kingdom 2010-12-01 08:26:00         6
# 1  United Kingdom 2010-12-01 09:02:00         6
# 2  United Kingdom 2010-12-01 09:32:00         6
# 3  United Kingdom 2010-12-01 10:19:00        64
# 4  United Kingdom 2010-12-01 10:39:00        32

# %%
app = dash.Dash(__name__)

# Agregar columnas de año y mes para facilitar el filtrado
filtered_data['Year'] = filtered_data['InvoiceDate'].dt.year
filtered_data['Month'] = filtered_data['InvoiceDate'].dt.month

# Layout de la aplicación web
app.layout = html.Div([
    html.H1("Cantidad vendida por día en el Reino Unido"),
    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': year, 'value': year} for year in filtered_data['Year'].unique()],
        value=filtered_data['Year'].max()
    ),
    dcc.Dropdown(
        id='month-dropdown',
        options=[{'label': month, 'value': month} for month in filtered_data['Month'].unique()],
        value=filtered_data['Month'].max()
    ),
    dcc.Graph(id='line-chart')
])

# Callback para actualizar el gráfico en función de las selecciones en los menús desplegables
@app.callback(
    Output('line-chart', 'figure'),
    Input('year-dropdown', 'value'),
    Input('month-dropdown', 'value')
)
def update_line_chart(selected_year, selected_month):
    filtered_data_filtered = filtered_data[(filtered_data['Year'] == selected_year) & (filtered_data['Month'] == selected_month)]
    fig = px.line(filtered_data_filtered, x='InvoiceDate', y='Quantity', title=f'Cantidad vendida por día en el Reino Unido ({selected_year}/{selected_month})')
    return fig

# Ejecutar la aplicación Dash
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 7. Create an interactive scatter plot that plots number of invoices (x-axis) vs. number of customers (y-axis) and the plot points represent individual products. Add two sliders that control the x and y axis ranges.

# %% [markdown]
# ## 8. Creat an interactive bar chart that shows revenue by product description. Add a text field widget that filters the results to show the product that contain the text entered in their description.
